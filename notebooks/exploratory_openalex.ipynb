# %% [markdown]
# # Exploratory OpenAlex
#
# Use this notebook to inspect raw or normalized OpenAlex data. Core pipeline logic lives in `src/`, not here.

# %%
# Example: load normalized data (after running fetch + prepare)
# from pathlib import Path
# import pandas as pd
# from scholarly_outcome_prediction.utils.io import read_parquet
# df = read_parquet(Path("data/processed/openalex_sample_100.parquet"))
# df.head()
